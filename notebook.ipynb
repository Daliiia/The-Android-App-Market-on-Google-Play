# %% [markdown]
# ## 1. Introduction
# <p><img src="https://assets.datacamp.com/production/project_1197/img/google_play_store.png" alt="Google Play logo"></p>
# <p>Mobile apps are everywhere. They are easy to create and can be very lucrative from the business standpoint. Specifically, Android is expanding as an operating system and has captured more than 74% of the total market<sup><a href="https://www.statista.com/statistics/272698/global-market-share-held-by-mobile-operating-systems-since-2009">[1]</a></sup>. </p>
# <p>The Google Play Store apps data has enormous potential to facilitate data-driven decisions and insights for businesses. In this notebook, we will analyze the Android app market by comparing ~10k apps in Google Play across different categories. We will also use the user reviews to draw a qualitative comparision between the apps.</p>
# <p>The dataset you will use here was scraped from Google Play Store in September 2018 and was published on <a href="https://www.kaggle.com/lava18/google-play-store-apps">Kaggle</a>. Here are the details: <br>
# <br></p>
# <div style="background-color: #efebe4; color: #05192d; text-align:left; vertical-align: middle; padding: 15px 25px 15px 25px; line-height: 1.6;">
#     <div style="font-size:20px"><b>datasets/apps.csv</b></div>
# This file contains all the details of the apps on Google Play. There are 9 features that describe a given app.
# <ul>
#     <li><b>App:</b> Name of the app</li>
#     <li><b>Category:</b> Category of the app. Some examples are: ART_AND_DESIGN, FINANCE, COMICS, BEAUTY etc.</li>
#     <li><b>Rating:</b> The current average rating (out of 5) of the app on Google Play</li>
#     <li><b>Reviews:</b> Number of user reviews given on the app</li>
#     <li><b>Size:</b> Size of the app in MB (megabytes)</li>
#     <li><b>Installs:</b> Number of times the app was downloaded from Google Play</li>
#     <li><b>Type:</b> Whether the app is paid or free</li>
#     <li><b>Price:</b> Price of the app in US$</li>
#     <li><b>Last Updated:</b> Date on which the app was last updated on Google Play </li>
#
# </ul>
# </div>
# <div style="background-color: #efebe4; color: #05192d; text-align:left; vertical-align: middle; padding: 15px 25px 15px 25px; line-height: 1.6;">
#     <div style="font-size:20px"><b>datasets/user_reviews.csv</b></div>
# This file contains a random sample of 100 <i>[most helpful first](https://www.androidpolice.com/2019/01/21/google-play-stores-redesigned-ratings-and-reviews-section-lets-you-easily-filter-by-star-rating/)</i> user reviews for each app. The text in each review has been pre-processed and passed through a sentiment analyzer.
# <ul>
#     <li><b>App:</b> Name of the app on which the user review was provided. Matches the `App` column of the `apps.csv` file</li>
#     <li><b>Review:</b> The pre-processed user review text</li>
#     <li><b>Sentiment Category:</b> Sentiment category of the user review - Positive, Negative or Neutral</li>
#     <li><b>Sentiment Score:</b> Sentiment score of the user review. It lies between [-1,1]. A higher score denotes a more positive sentiment.</li>
#
# </ul>
# </div>
# <p>From here on, it will be your task to explore and manipulate the data until you are able to answer the three questions described in the instructions panel.<br></p>

# %%
# Use this cell to begin your analysis, and add as many as you would like!
import pandas as pd 
apps=pd.read_csv("datasets/apps.csv")

# %%
apps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type  Price      Last Updated
# 0      159  19.0      10,000+  Free    0.0   January 7, 2018
# 1      967  14.0     500,000+  Free    0.0  January 15, 2018
# 2    87510   8.7   5,000,000+  Free    0.0    August 1, 2018
# 3   215644  25.0  50,000,000+  Free    0.0      June 8, 2018
# 4      967   2.8     100,000+  Free    0.0     June 20, 2018

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 9 columns):
# App             9659 non-null object
# Category        9659 non-null object
# Rating          8196 non-null float64
# Reviews         9659 non-null int64
# Size            8432 non-null float64
# Installs        9659 non-null object
# Type            9659 non-null object
# Price           9659 non-null float64
# Last Updated    9659 non-null object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 679.2+ KB

# %%
installs_str=[]
for i in apps["Installs"]:
    if len(i)!=1:
        installs_str.append(i[:-1])
    else:
        installs_str.append(i)
installs_int=[]
for j in installs_str:
    without_comma=j.replace(',','')
    installs_int.append(int(without_comma))
    
apps['Installs']=installs_int
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_348/648338203.py in <module>
#       1 installs_str=[]
# ----> 2 for i in apps["Installs"]:
#       3     if len(i)!=1:
#       4         installs_str.append(i[:-1])
#       5     else:
#
# NameError: name 'apps' is not defined

# %%
app_category_info=apps.groupby('Category')[['Price','Rating']].mean()
app_category_info['Number of apps']=apps["Category"].value_counts()
app_category_info.rename(columns={'Category': 'Category', 'Price': 'Average price','Rating':'Average rating', 'Number of apps':'Number of apps'}, inplace=True)

app_category_info
# Out:
#                      Average price  Average rating  Number of apps
# Category
# ART_AND_DESIGN            0.093281        4.357377              64
# AUTO_AND_VEHICLES         0.158471        4.190411              85
# BEAUTY                    0.000000        4.278571              53
# BOOKS_AND_REFERENCE       0.539505        4.344970             222
# BUSINESS                  0.417357        4.098479             420
# COMICS                    0.000000        4.181481              56
# COMMUNICATION             0.263937        4.121484             315
# DATING                    0.160468        3.970149             171
# EDUCATION                 0.150924        4.364407             119
# ENTERTAINMENT             0.078235        4.135294             102
# EVENTS                    1.718594        4.435556              64
# FAMILY                    1.309967        4.179664            1832
# FINANCE                   8.408203        4.115563             345
# FOOD_AND_DRINK            0.075714        4.172340             112
# GAME                      0.296465        4.247368             959
# HEALTH_AND_FITNESS        0.223438        4.243033             288
# HOUSE_AND_HOME            0.000000        4.150000              74
# LIBRARIES_AND_DEMO        0.011786        4.178125              84
# LIFESTYLE                 6.398022        4.093355             369
# MAPS_AND_NAVIGATION       0.205725        4.036441             131
# MEDICAL                   2.520759        4.166552             395
# NEWS_AND_MAGAZINES        0.015669        4.121569             254
# PARENTING                 0.159667        4.300000              60
# PERSONALIZATION           0.400213        4.332215             376
# PHOTOGRAPHY               0.420925        4.157414             281
# PRODUCTIVITY              0.670936        4.183389             374
# SHOPPING                  0.027129        4.230000             202
# SOCIAL                    0.066820        4.247291             239
# SPORTS                    0.307692        4.216154             325
# TOOLS                     0.323156        4.039554             827
# TRAVEL_AND_LOCAL          0.228082        4.069519             219
# VIDEO_PLAYERS             0.064172        4.044595             163
# WEATHER                   0.410380        4.243056              79

# %%
apps_free=apps[apps['Type']=='Free']
apps_free_finance=apps_free[apps_free['Category']=='FINANCE']
apps_free_finance['App']
# Out:
# 837                                                K PLUS
# 838                                           ING Banking
# 839                                     Citibanamex Movil
# 840                                       The postal bank
# 841                                           KTB Netbank
# 842                                       Mobile Bancomer
# 843                                         Nedbank Money
# 844                                              SCB EASY
# 845                                               CASHIER
# 846                                          Rabo Banking
# 847                                Capitec Remote Banking
# 848                                             Itau bank
# 849                                                Nubank
# 850                              The Societe Generale App
# 851                                                   IKO
# 852                                              Cash App
# 853                          Standard Bank / Stanbic Bank
# 854                                     Bualuang mBanking
# 855                                Intesa Sanpaolo Mobile
# 856                                    UBA Mobile Banking
# 857                                            BBVA Spain
# 858                                           MyMo by GSB
# 859                                            VTB-Online
# 860                                Ecobank Mobile Banking
# 861                                         Banorte Movil
# 862                                    Wells Fargo Mobile
# 863                                          Credit Karma
# 864                                        BZWBK24 mobile
# 865                                                PayPal
# 866                                   Capital One® Mobile
#                               ...
# 9117                              FD Community FCU Mobile
# 9122                                Policy And FD Manager
# 9127         FD Calculator | Term Deposit | Fixed Deposit
# 9129                           Financial Calculator India
# 9130    FD Calculator (EMI, SIP, RD & Loan Eligilibility)
# 9132                        EMI, FD, RD - Bank Calculator
# 9134                                     RD/FD Calculator
# 9137                          Fix Deposit Calculator (FD)
# 9138                               FD Interest Calculator
# 9139                           Deposit Calculator FD & RD
# 9141                                   Banking Calculator
# 9144                        EMI/FD/RD/PV/IRR/BEP/EOQ Calc
# 9145       EMI Calculator | FD Calculator | RD calculator
# 9149                          Santa Fe FCU Mobile Banking
# 9152                                  FE CREDIT - TET VUI
# 9159                        Caprock Santa Fe Credit Union
# 9169                                               FE CPS
# 9189                                            FG Wallet
# 9245                                            FH Wallet
# 9252                           First Hawaiian Bank Mobile
# 9295                                               FI CFL
# 9453                       PriorityONE Credit Union of Fl
# 9468                        First Federal Bank of Florida
# 9488                          SB · FN 1870 Mobile Banking
# 9522                                         FO BOULANGER
# 9540                                           BankNordik
# 9564                                           FP Markets
# 9565                                              FP Boss
# 9572                                               FP FCU
# 9636                                 Gold Quote - Gold.fr
# Name: App, Length: 328, dtype: object

# %%
reviews=pd.read_csv("datasets/user_reviews.csv")
reviews.tail(100)
# Out:
#                                   App  \
# 64195  Hotwire Hotel & Car Rental App
# 64196  Housing-Real Estate & Property
# 64197  Housing-Real Estate & Property
# 64198  Housing-Real Estate & Property
# 64199  Housing-Real Estate & Property
# 64200  Housing-Real Estate & Property
# 64201  Housing-Real Estate & Property
# 64202  Housing-Real Estate & Property
# 64203  Housing-Real Estate & Property
# 64204  Housing-Real Estate & Property
# 64205  Housing-Real Estate & Property
# 64206  Housing-Real Estate & Property
# 64207  Housing-Real Estate & Property
# 64208  Housing-Real Estate & Property
# 64209  Housing-Real Estate & Property
# 64210  Housing-Real Estate & Property
# 64211  Housing-Real Estate & Property
# 64212  Housing-Real Estate & Property
# 64213  Housing-Real Estate & Property
# 64214  Housing-Real Estate & Property
# 64215  Housing-Real Estate & Property
# 64216  Housing-Real Estate & Property
# 64217  Housing-Real Estate & Property
# 64218  Housing-Real Estate & Property
# 64219  Housing-Real Estate & Property
# 64220  Housing-Real Estate & Property
# 64221  Housing-Real Estate & Property
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64224  Housing-Real Estate & Property
# ...                               ...
# 64265     Houzz Interior Design Ideas
# 64266     Houzz Interior Design Ideas
# 64267     Houzz Interior Design Ideas
# 64268     Houzz Interior Design Ideas
# 64269     Houzz Interior Design Ideas
# 64270     Houzz Interior Design Ideas
# 64271     Houzz Interior Design Ideas
# 64272     Houzz Interior Design Ideas
# 64273     Houzz Interior Design Ideas
# 64274     Houzz Interior Design Ideas
# 64275     Houzz Interior Design Ideas
# 64276     Houzz Interior Design Ideas
# 64277     Houzz Interior Design Ideas
# 64278     Houzz Interior Design Ideas
# 64279     Houzz Interior Design Ideas
# 64280     Houzz Interior Design Ideas
# 64281     Houzz Interior Design Ideas
# 64282     Houzz Interior Design Ideas
# 64283     Houzz Interior Design Ideas
# 64284     Houzz Interior Design Ideas
# 64285     Houzz Interior Design Ideas
# 64286     Houzz Interior Design Ideas
# 64287     Houzz Interior Design Ideas
# 64288     Houzz Interior Design Ideas
# 64289     Houzz Interior Design Ideas
# 64290     Houzz Interior Design Ideas
# 64291     Houzz Interior Design Ideas
# 64292     Houzz Interior Design Ideas
# 64293     Houzz Interior Design Ideas
# 64294     Houzz Interior Design Ideas
#
#                                                   Review Sentiment Category  \
# 64195                                                NaN                NaN
# 64196  Incorrect listings. The agents show property d...           Negative
# 64197  Pathetic app.All posted leads owner either old...           Negative
# 64198  It's waste app... Most properties 2017... And ...           Positive
# 64199  Filters useless I posted owners shows agents a...           Negative
# 64200  Why business? Your filters don't work.. redire...            Neutral
# 64201         Filters work... Searching property useless           Negative
# 64202                                                NaN                NaN
# 64203                                                NaN                NaN
# 64204                                                NaN                NaN
# 64205   I want list property sale option. Please connect            Neutral
# 64206                                                NaN                NaN
# 64207                                               Good           Positive
# 64208                                                NaN                NaN
# 64209  Awesome app.. But prices date? Awesome app. Gi...           Positive
# 64210                                                NaN                NaN
# 64211                                                NaN                NaN
# 64212                                                NaN                NaN
# 64213  This worse ever. They give graphic pictures pr...           Negative
# 64214                                                NaN                NaN
# 64215  Horrible app. I wanted list property get aroun...           Negative
# 64216  Worst app. We get nothing Time waste . They up...           Negative
# 64217  I able set range 1cr, scroll space 0-1cr range...           Positive
# 64218  What nonsensical app.. doesn't owner postings ...            Neutral
# 64219                                                NaN                NaN
# 64220  No response support team. After I login, unabl...           Negative
# 64221  Everything old stuff neither clear sold proper...           Positive
# 64222  Most ads older many agents ..not much owner po...           Positive
# 64223  If photos posted portal load, fit purpose. I'm...           Positive
# 64224                                                NaN                NaN
# ...                                                  ...                ...
# 64265                                                NaN                NaN
# 64266                                                NaN                NaN
# 64267                                                NaN                NaN
# 64268                                                NaN                NaN
# 64269                                                NaN                NaN
# 64270                                                NaN                NaN
# 64271                                                NaN                NaN
# 64272                                                NaN                NaN
# 64273                                                NaN                NaN
# 64274                                                NaN                NaN
# 64275                                                NaN                NaN
# 64276                                                NaN                NaN
# 64277                                                NaN                NaN
# 64278                                                NaN                NaN
# 64279                                                NaN                NaN
# 64280                                                NaN                NaN
# 64281                                                NaN                NaN
# 64282                                                NaN                NaN
# 64283                                                NaN                NaN
# 64284                                                NaN                NaN
# 64285                                                NaN                NaN
# 64286                                                NaN                NaN
# 64287                                                NaN                NaN
# 64288                                                NaN                NaN
# 64289                                                NaN                NaN
# 64290                                                NaN                NaN
# 64291                                                NaN                NaN
# 64292                                                NaN                NaN
# 64293                                                NaN                NaN
# 64294                                                NaN                NaN
#
#        Sentiment Score
# 64195              NaN
# 64196        -0.025000
# 64197        -0.362500
# 64198         0.266667
# 64199        -0.500000
# 64200         0.000000
# 64201        -0.500000
# 64202              NaN
# 64203              NaN
# 64204              NaN
# 64205         0.000000
# 64206              NaN
# 64207         0.700000
# 64208              NaN
# 64209         0.509375
# 64210              NaN
# 64211              NaN
# 64212              NaN
# 64213        -0.081250
# 64214              NaN
# 64215        -0.528571
# 64216        -0.400000
# 64217         0.233333
# 64218         0.000000
# 64219              NaN
# 64220        -0.377778
# 64221         0.021591
# 64222         0.173333
# 64223         0.225000
# 64224              NaN
# ...                ...
# 64265              NaN
# 64266              NaN
# 64267              NaN
# 64268              NaN
# 64269              NaN
# 64270              NaN
# 64271              NaN
# 64272              NaN
# 64273              NaN
# 64274              NaN
# 64275              NaN
# 64276              NaN
# 64277              NaN
# 64278              NaN
# 64279              NaN
# 64280              NaN
# 64281              NaN
# 64282              NaN
# 64283              NaN
# 64284              NaN
# 64285              NaN
# 64286              NaN
# 64287              NaN
# 64288              NaN
# 64289              NaN
# 64290              NaN
# 64291              NaN
# 64292              NaN
# 64293              NaN
# 64294              NaN
#
# [100 rows x 4 columns]

# %%
merged_df=pd.merge(apps_free_finance,reviews,on='App')
merged_df
# Out:
#                                App Category  Rating  Reviews  Size  Installs  \
# 0                Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 1                Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 2                Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 3                Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 4                Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 5                Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 6                Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 7                Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 8                Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 9                Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 10               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 11               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 12               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 13               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 15               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 16               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 17               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 18               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 19               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 20               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 21               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 22               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 23               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 24               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 25               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 26               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 27               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 28               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 29               Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# ...                            ...      ...     ...      ...   ...       ...
# 2170  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2171  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2172  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2173  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2174  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2175  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2176  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2177  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2178  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2179  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2180  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2181  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2182  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2183  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2184  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2185  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2186  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2187  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2188  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2189  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2190  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2191  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2192  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2193  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2194  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2195  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2196  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2197  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2198  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 2199  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
#
#       Type  Price   Last Updated  \
# 0     Free    0.0  July 27, 2018
# 1     Free    0.0  July 27, 2018
# 2     Free    0.0  July 27, 2018
# 3     Free    0.0  July 27, 2018
# 4     Free    0.0  July 27, 2018
# 5     Free    0.0  July 27, 2018
# 6     Free    0.0  July 27, 2018
# 7     Free    0.0  July 27, 2018
# 8     Free    0.0  July 27, 2018
# 9     Free    0.0  July 27, 2018
# 10    Free    0.0  July 27, 2018
# 11    Free    0.0  July 27, 2018
# 12    Free    0.0  July 27, 2018
# 13    Free    0.0  July 27, 2018
# 14    Free    0.0  July 27, 2018
# 15    Free    0.0  July 27, 2018
# 16    Free    0.0  July 27, 2018
# 17    Free    0.0  July 27, 2018
# 18    Free    0.0  July 27, 2018
# 19    Free    0.0  July 27, 2018
# 20    Free    0.0  July 27, 2018
# 21    Free    0.0  July 27, 2018
# 22    Free    0.0  July 27, 2018
# 23    Free    0.0  July 27, 2018
# 24    Free    0.0  July 27, 2018
# 25    Free    0.0  July 27, 2018
# 26    Free    0.0  July 27, 2018
# 27    Free    0.0  July 27, 2018
# 28    Free    0.0  July 27, 2018
# 29    Free    0.0  July 27, 2018
# ...    ...    ...            ...
# 2170  Free    0.0  July 17, 2018
# 2171  Free    0.0  July 17, 2018
# 2172  Free    0.0  July 17, 2018
# 2173  Free    0.0  July 17, 2018
# 2174  Free    0.0  July 17, 2018
# 2175  Free    0.0  July 17, 2018
# 2176  Free    0.0  July 17, 2018
# 2177  Free    0.0  July 17, 2018
# 2178  Free    0.0  July 17, 2018
# 2179  Free    0.0  July 17, 2018
# 2180  Free    0.0  July 17, 2018
# 2181  Free    0.0  July 17, 2018
# 2182  Free    0.0  July 17, 2018
# 2183  Free    0.0  July 17, 2018
# 2184  Free    0.0  July 17, 2018
# 2185  Free    0.0  July 17, 2018
# 2186  Free    0.0  July 17, 2018
# 2187  Free    0.0  July 17, 2018
# 2188  Free    0.0  July 17, 2018
# 2189  Free    0.0  July 17, 2018
# 2190  Free    0.0  July 17, 2018
# 2191  Free    0.0  July 17, 2018
# 2192  Free    0.0  July 17, 2018
# 2193  Free    0.0  July 17, 2018
# 2194  Free    0.0  July 17, 2018
# 2195  Free    0.0  July 17, 2018
# 2196  Free    0.0  July 17, 2018
# 2197  Free    0.0  July 17, 2018
# 2198  Free    0.0  July 17, 2018
# 2199  Free    0.0  July 17, 2018
#
#                                                  Review Sentiment Category  \
# 0     Forget paying app, designed make fail payments...           Negative
# 1     It's working expected, talking best bank Mexic...           Positive
# 2     It has many problems with Android 8.1. You can...           Positive
# 3     I changed my phone to a Xiaomi Redmi Note 5, t...           Positive
# 4     In her eagerness to make her look pretty with ...           Negative
# 5     I can not activate my mobile Netkey because it...           Positive
# 6     The mobile netkey does not work on Android 8.1...            Neutral
# 7     The new update is frozen on the home screen wi...           Positive
# 8     Almost everything works well, only that the tr...            Neutral
# 9     In my case after the update stopped working, t...           Positive
# 10    2018-08-01: Android 8.1 is still supported ?, ...           Positive
# 11    The whole system crashes (literally, causes th...           Positive
# 12    It is not compatible with 8.1 gives many probl...           Positive
# 13    The new update works very well in Samsung 7 Ed...           Positive
# 14    I placed wrong fingerprint, I tried open sessi...           Negative
# 15    Needs improvement. Wanted Mobile Netkey find I...           Negative
# 16    I have purchased a new cell phone, keep saying...           Positive
# 17    Horrible! You can not see the charges made unt...           Negative
# 18    After some updates I can finally use the app, ...           Positive
# 19    It's already good, only if you keep working in...           Positive
# 20    If I dont sign I can't sign 10 minutes passed ...           Negative
# 21    I LIKE A LOT, IT IS VERY ACCESSIBLE AND YOU CA...           Positive
# 22    It is a great service although I had some prob...           Positive
# 23    Back the problems that the operating system is...            Neutral
# 24    I see that many complain, but the truth is tha...           Positive
# 25    They keep uploading updates, the application k...           Negative
# 26    Has improved a lot. At this moment it is a ver...           Positive
# 27    It needs quick transfers save accounts/debit c...           Negative
# 28    It works very well to review the accounts aest...           Positive
# 29    The biggest change I noticed with the last upd...            Neutral
# ...                                                 ...                ...
# 2170                                                NaN                NaN
# 2171                                                NaN                NaN
# 2172                                                NaN                NaN
# 2173                                                NaN                NaN
# 2174                                                NaN                NaN
# 2175                                                NaN                NaN
# 2176                                                NaN                NaN
# 2177                                                NaN                NaN
# 2178                                                NaN                NaN
# 2179                                                NaN                NaN
# 2180                                                NaN                NaN
# 2181                                                NaN                NaN
# 2182                                                NaN                NaN
# 2183                                                NaN                NaN
# 2184                                                NaN                NaN
# 2185                                                NaN                NaN
# 2186                                                NaN                NaN
# 2187                                                NaN                NaN
# 2188                                                NaN                NaN
# 2189                                                NaN                NaN
# 2190                                                NaN                NaN
# 2191                                                NaN                NaN
# 2192                                                NaN                NaN
# 2193                                                NaN                NaN
# 2194                                                NaN                NaN
# 2195                                                NaN                NaN
# 2196                                                NaN                NaN
# 2197                                                NaN                NaN
# 2198                                                NaN                NaN
# 2199                                                NaN                NaN
#
#       Sentiment Score
# 0           -0.500000
# 1            0.400000
# 2            0.250000
# 3            0.175000
# 4           -0.158333
# 5            0.116667
# 6            0.000000
# 7            0.168182
# 8            0.000000
# 9            0.243750
# 10           0.291667
# 11           0.200000
# 12           0.500000
# 13           0.157576
# 14          -0.126667
# 15          -0.100000
# 16           0.136364
# 17          -0.187500
# 18           0.455000
# 19           0.175000
# 20          -0.600000
# 21           0.487500
# 22           0.433333
# 23           0.000000
# 24           0.833333
# 25          -0.097727
# 26           0.505000
# 27          -0.111111
# 28           0.722000
# 29           0.000000
# ...               ...
# 2170              NaN
# 2171              NaN
# 2172              NaN
# 2173              NaN
# 2174              NaN
# 2175              NaN
# 2176              NaN
# 2177              NaN
# 2178              NaN
# 2179              NaN
# 2180              NaN
# 2181              NaN
# 2182              NaN
# 2183              NaN
# 2184              NaN
# 2185              NaN
# 2186              NaN
# 2187              NaN
# 2188              NaN
# 2189              NaN
# 2190              NaN
# 2191              NaN
# 2192              NaN
# 2193              NaN
# 2194              NaN
# 2195              NaN
# 2196              NaN
# 2197              NaN
# 2198              NaN
# 2199              NaN
#
# [2200 rows x 12 columns]

# %%
df_apps_finance_free_avg_score=pd.DataFrame(df_apps_finance_free.groupby('App')['Sentiment Score'].mean())
df_apps_finance_free_avg_score
user_feedback= df_apps_finance_free_avg_score.sort_values('Sentiment Score',ascending=False)
user_feedback
# Out:
#                                                  Sentiment Score
# App
# Expense IQ Money Manager                                0.568182
# BBVA Compass Banking                                    0.528652
# Citibanamex Movil                                       0.509731
# Capitec Remote Banking                                  0.475844
# Cash App                                                0.474445
# BBVA Spain                                              0.470015
# A+ Mobile                                               0.428862
# Bualuang mBanking                                       0.426832
# Chime - Mobile Banking                                  0.406192
# Ecobank Mobile Banking                                  0.392405
# Credit Sesame                                           0.390469
# Digit Save Money Automatically                          0.352837
# Capital One® Mobile                                     0.342527
# Credit Karma                                            0.318145
# Everlance: Free Mileage Log                             0.317299
# Google Pay                                              0.304710
# Bank of America Mobile Banking                          0.293143
# FREE Stock Market Trading Tips                          0.259672
# GCash - Buy Load, Pay Bills, Send Money                 0.259131
# Associated Credit Union Mobile                          0.236410
# ACE Elite                                               0.235025
# Fortune City - A Finance App                            0.224637
# Discover Mobile                                         0.221739
# Experian - Free Credit Report                           0.221395
# BankMobile Vibe App                                     0.215661
# BZWBK24 mobile                                          0.196290
# Banorte Movil                                           0.181294
# Even - organize your money, get paid early              0.168968
# CreditWise from Capital One                             0.167560
# Bluebird by American Express                            0.155000
# Fresh EBT - Food Stamp Balance                          0.143807
# Citi Mobile®                                            0.127221
# Bloomberg Professional                                  0.113847
# Branch                                                  0.076487
# Amex Mobile                                             0.069002
# Citizens Bank Mobile Banking                            0.030457
# GoBank                                                  0.030107
# Betterment                                              0.009130
# Fox Business                                           -0.003813
# CNBC: Breaking Business News & Live Market Data        -0.005141
# Current debit card and app made for teens              -0.008581
# E*TRADE Mobile                                         -0.008937
# Chase Mobile                                           -0.191207
# Acorns - Invest Spare Change                                 NaN
# Barclays US for Android                                      NaN
# HDFC Bank MobileBanking                                      NaN

# %%
top_10_user_feedback=user_feedback.iloc[:10]
top_10_user_feedback
# Out:
#                           Sentiment Score
# App
# Expense IQ Money Manager         0.568182
# BBVA Compass Banking             0.528652
# Citibanamex Movil                0.509731
# Capitec Remote Banking           0.475844
# Cash App                         0.474445
# BBVA Spain                       0.470015
# A+ Mobile                        0.428862
# Bualuang mBanking                0.426832
# Chime - Mobile Banking           0.406192
# Ecobank Mobile Banking           0.392405
